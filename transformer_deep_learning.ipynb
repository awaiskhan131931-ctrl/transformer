# %% [markdown]
# <a href="https://colab.research.google.com/github/awaiskhan131931-ctrl/transformer/blob/main/transformer_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %% [markdown]
# **take a sample**

# %%
english = [
    "hello",
    "how are you",
    "i am fine",
    "what is your name",
    "my name is awais",
    "where are you going",
    "i am going to school",
    "do you like tea",
    "yes i like tea",
    "i love pakistan",
    "good morning",
    "good night",
    "see you later",
    "come here",
    "sit down",
    "open the door",
    "close the window",
    "what are you doing",
    "i am reading a book",
    "this is my friend",
    "i am hungry",
    "i am tired",
    "please help me",
    "how old are you",
    "i am twenty years old",
    "where do you live",
    "i live in swat",
    "what is this",
    "this is a computer",
    "i like programming",
    "tensorflow is powerful",
    "deep learning is interesting",
    "machine learning is the future",
    "the weather is very hot",
    "today is friday",
    "i want to learn ai",
    "can you teach me",
    "i have a laptop",
    "my laptop is hp",
    "the internet is slow",
    "i am watching a movie",
    "he is my brother",
    "she is my sister",
    "we are students",
    "they are playing cricket",
    "the baby is sleeping",
    "please give me water",
    "i need some food",
    "this car is very fast",
    "the cat is under the table"
]

poshto = [
    "<start> سلام <end>",
    "<start> ته څنګه يې <end>",
    "<start> زه ښه يم <end>",
    "<start> ستا نوم څه دی <end>",
    "<start> زما نوم اويس دی <end>",
    "<start> ته چېرته ځې <end>",
    "<start> زه ښوونځي ته ځم <end>",
    "<start> ته چای خوښوې <end>",
    "<start> هو زه چای خوښوم <end>",
    "<start> زه پاکستان سره مينه لرم <end>",
    "<start> سهار مو پخير <end>",
    "<start> شپه مو پخير <end>",
    "<start> بيا به سره ګورو <end>",
    "<start> دلته راشه <end>",
    "<start> کښېنه <end>",
    "<start> دروازه خلاصه کړه <end>",
    "<start> کړکۍ بنده کړه <end>",
    "<start> ته څه کوې <end>",
    "<start> زه کتاب لولم <end>",
    "<start> دا زما ملګری دی <end>",
    "<start> زه وږی يم <end>",
    "<start> زه ستړی يم <end>",
    "<start> مهرباني وکړه مرسته راسره وکړه <end>",
    "<start> ستا عمر څو کاله دی <end>",
    "<start> زما عمر شل کاله دی <end>",
    "<start> ته چېرته اوسېږې <end>",
    "<start> زه په سوات کې اوسېږم <end>",
    "<start> دا څه دي <end>",
    "<start> دا کمپيوټر دی <end>",
    "<start> زه پروګرامنګ خوښوم <end>",
    "<start> ټېنسرفلو ځواکمن دی <end>",
    "<start> ژوره زده کړه زړه پورې ده <end>",
    "<start> ماشين زده کړه راتلونکې ده <end>",
    "<start> هوا ډېره ګرمه ده <end>",
    "<start> نن جمعه ده <end>",
    "<start> زه مصنوعي ځيرکتيا زده کول غواړم <end>",
    "<start> ته ما ته زده کړه راکولی شې <end>",
    "<start> زما سره لپټاپ شته <end>",
    "<start> زما لپټاپ HP دی <end>",
    "<start> انټرنېټ ډېر ورو دی <end>",
    "<start> زه فلم ګورم <end>",
    "<start> هغه زما ورور دی <end>",
    "<start> هغه زما خور ده <end>",
    "<start> موږ زده کوونکي يو <end>",
    "<start> هغوی کرکټ لوبوي <end>",
    "<start> ماشوم ويده دی <end>",
    "<start> مهرباني وکړئ اوبه راکړئ <end>",
    "<start> زه خوراک ته اړتيا لرم <end>",
    "<start> دا موټر ډېر تېز دی <end>",
    "<start> پيشو د مېز لاندې ده <end>"
]

# %% [markdown]
# **tokenizaion**

# %%
eng_tokenizer = Tokenizer()
eng_tokenizer.fit_on_texts(english)

poshto_tokenizer = Tokenizer()
poshto_tokenizer.fit_on_texts(poshto)


print("English Tokenizer:")
print(eng_tokenizer.word_index)
print(eng_tokenizer.word_counts)
print(len(eng_tokenizer.word_index) + 1)


#====================

print("\nPoshto Tokenizer:")
print(poshto_tokenizer.word_index)
print(poshto_tokenizer.word_counts)
print(len(poshto_tokenizer.word_index) + 1)
# Out:
# English Tokenizer:
# {'is': 1, 'i': 2, 'you': 3, 'the': 4, 'am': 5, 'are': 6, 'my': 7, 'a': 8, 'this': 9, 'what': 10, 'like': 11, 'me': 12, 'how': 13, 'name': 14, 'where': 15, 'going': 16, 'to': 17, 'do': 18, 'tea': 19, 'good': 20, 'please': 21, 'old': 22, 'live': 23, 'learning': 24, 'very': 25, 'laptop': 26, 'hello': 27, 'fine': 28, 'your': 29, 'awais': 30, 'school': 31, 'yes': 32, 'love': 33, 'pakistan': 34, 'morning': 35, 'night': 36, 'see': 37, 'later': 38, 'come': 39, 'here': 40, 'sit': 41, 'down': 42, 'open': 43, 'door': 44, 'close': 45, 'window': 46, 'doing': 47, 'reading': 48, 'book': 49, 'friend': 50, 'hungry': 51, 'tired': 52, 'help': 53, 'twenty': 54, 'years': 55, 'in': 56, 'swat': 57, 'computer': 58, 'programming': 59, 'tensorflow': 60, 'powerful': 61, 'deep': 62, 'interesting': 63, 'machine': 64, 'future': 65, 'weather': 66, 'hot': 67, 'today': 68, 'friday': 69, 'want': 70, 'learn': 71, 'ai': 72, 'can': 73, 'teach': 74, 'have': 75, 'hp': 76, 'internet': 77, 'slow': 78, 'watching': 79, 'movie': 80, 'he': 81, 'brother': 82, 'she': 83, 'sister': 84, 'we': 85, 'students': 86, 'they': 87, 'playing': 88, 'cricket': 89, 'baby': 90, 'sleeping': 91, 'give': 92, 'water': 93, 'need': 94, 'some': 95, 'food': 96, 'car': 97, 'fast': 98, 'cat': 99, 'under': 100, 'table': 101}
# OrderedDict({'hello': 1, 'how': 2, 'are': 6, 'you': 8, 'i': 14, 'am': 7, 'fine': 1, 'what': 3, 'is': 17, 'your': 1, 'name': 2, 'my': 5, 'awais': 1, 'where': 2, 'going': 2, 'to': 2, 'school': 1, 'do': 2, 'like': 3, 'tea': 2, 'yes': 1, 'love': 1, 'pakistan': 1, 'good': 2, 'morning': 1, 'night': 1, 'see': 1, 'later': 1, 'come': 1, 'here': 1, 'sit': 1, 'down': 1, 'open': 1, 'the': 8, 'door': 1, 'close': 1, 'window': 1, 'doing': 1, 'reading': 1, 'a': 4, 'book': 1, 'this': 4, 'friend': 1, 'hungry': 1, 'tired': 1, 'please': 2, 'help': 1, 'me': 3, 'old': 2, 'twenty': 1, 'years': 1, 'live': 2, 'in': 1, 'swat': 1, 'computer': 1, 'programming': 1, 'tensorflow': 1, 'powerful': 1, 'deep': 1, 'learning': 2, 'interesting': 1, 'machine': 1, 'future': 1, 'weather': 1, 'very': 2, 'hot': 1, 'today': 1, 'friday': 1, 'want': 1, 'learn': 1, 'ai': 1, 'can': 1, 'teach': 1, 'have': 1, 'laptop': 2, 'hp': 1, 'internet': 1, 'slow': 1, 'watching': 1, 'movie': 1, 'he': 1, 'brother': 1, 'she': 1, 'sister': 1, 'we': 1, 'students': 1, 'they': 1, 'playing': 1, 'cricket': 1, 'baby': 1, 'sleeping': 1, 'give': 1, 'water': 1, 'need': 1, 'some': 1, 'food': 1, 'car': 1, 'fast': 1, 'cat': 1, 'under': 1, 'table': 1})
# 102
#
# Poshto Tokenizer:
# {'start': 1, 'end': 2, 'زه': 3, 'دی': 4, 'ته': 5, 'زما': 6, 'ده': 7, 'کړه': 8, 'زده': 9, 'دا': 10, 'يم': 11, 'څه': 12, 'سره': 13, 'ستا': 14, 'نوم': 15, 'چېرته': 16, 'چای': 17, 'خوښوم': 18, 'لرم': 19, 'مو': 20, 'پخير': 21, 'مهرباني': 22, 'وکړه': 23, 'عمر': 24, 'کاله': 25, 'لپټاپ': 26, 'ډېر': 27, 'هغه': 28, 'سلام': 29, 'څنګه': 30, 'يې': 31, 'ښه': 32, 'اويس': 33, 'ځې': 34, 'ښوونځي': 35, 'ځم': 36, 'خوښوې': 37, 'هو': 38, 'پاکستان': 39, 'مينه': 40, 'سهار': 41, 'شپه': 42, 'بيا': 43, 'به': 44, 'ګورو': 45, 'دلته': 46, 'راشه': 47, 'کښېنه': 48, 'دروازه': 49, 'خلاصه': 50, 'کړکۍ': 51, 'بنده': 52, 'کوې': 53, 'کتاب': 54, 'لولم': 55, 'ملګری': 56, 'وږی': 57, 'ستړی': 58, 'مرسته': 59, 'راسره': 60, 'څو': 61, 'شل': 62, 'اوسېږې': 63, 'په': 64, 'سوات': 65, 'کې': 66, 'اوسېږم': 67, 'دي': 68, 'کمپيوټر': 69, 'پروګرامنګ': 70, 'ټېنسرفلو': 71, 'ځواکمن': 72, 'ژوره': 73, 'زړه': 74, 'پورې': 75, 'ماشين': 76, 'راتلونکې': 77, 'هوا': 78, 'ډېره': 79, 'ګرمه': 80, 'نن': 81, 'جمعه': 82, 'مصنوعي': 83, 'ځيرکتيا': 84, 'کول': 85, 'غواړم': 86, 'ما': 87, 'راکولی': 88, 'شې': 89, 'شته': 90, 'hp': 91, 'انټرنېټ': 92, 'ورو': 93, 'فلم': 94, 'ګورم': 95, 'ورور': 96, 'خور': 97, 'موږ': 98, 'کوونکي': 99, 'يو': 100, 'هغوی': 101, 'کرکټ': 102, 'لوبوي': 103, 'ماشوم': 104, 'ويده': 105, 'وکړئ': 106, 'اوبه': 107, 'راکړئ': 108, 'خوراک': 109, 'اړتيا': 110, 'موټر': 111, 'تېز': 112, 'پيشو': 113, 'د': 114, 'مېز': 115, 'لاندې': 116}
# OrderedDict({'start': 50, 'سلام': 1, 'end': 50, 'ته': 9, 'څنګه': 1, 'يې': 1, 'زه': 12, 'ښه': 1, 'يم': 3, 'ستا': 2, 'نوم': 2, 'څه': 3, 'دی': 12, 'زما': 7, 'اويس': 1, 'چېرته': 2, 'ځې': 1, 'ښوونځي': 1, 'ځم': 1, 'چای': 2, 'خوښوې': 1, 'هو': 1, 'خوښوم': 2, 'پاکستان': 1, 'سره': 3, 'مينه': 1, 'لرم': 2, 'سهار': 1, 'مو': 2, 'پخير': 2, 'شپه': 1, 'بيا': 1, 'به': 1, 'ګورو': 1, 'دلته': 1, 'راشه': 1, 'کښېنه': 1, 'دروازه': 1, 'خلاصه': 1, 'کړه': 5, 'کړکۍ': 1, 'بنده': 1, 'کوې': 1, 'کتاب': 1, 'لولم': 1, 'دا': 4, 'ملګری': 1, 'وږی': 1, 'ستړی': 1, 'مهرباني': 2, 'وکړه': 2, 'مرسته': 1, 'راسره': 1, 'عمر': 2, 'څو': 1, 'کاله': 2, 'شل': 1, 'اوسېږې': 1, 'په': 1, 'سوات': 1, 'کې': 1, 'اوسېږم': 1, 'دي': 1, 'کمپيوټر': 1, 'پروګرامنګ': 1, 'ټېنسرفلو': 1, 'ځواکمن': 1, 'ژوره': 1, 'زده': 5, 'زړه': 1, 'پورې': 1, 'ده': 6, 'ماشين': 1, 'راتلونکې': 1, 'هوا': 1, 'ډېره': 1, 'ګرمه': 1, 'نن': 1, 'جمعه': 1, 'مصنوعي': 1, 'ځيرکتيا': 1, 'کول': 1, 'غواړم': 1, 'ما': 1, 'راکولی': 1, 'شې': 1, 'لپټاپ': 2, 'شته': 1, 'hp': 1, 'انټرنېټ': 1, 'ډېر': 2, 'ورو': 1, 'فلم': 1, 'ګورم': 1, 'هغه': 2, 'ورور': 1, 'خور': 1, 'موږ': 1, 'کوونکي': 1, 'يو': 1, 'هغوی': 1, 'کرکټ': 1, 'لوبوي': 1, 'ماشوم': 1, 'ويده': 1, 'وکړئ': 1, 'اوبه': 1, 'راکړئ': 1, 'خوراک': 1, 'اړتيا': 1, 'موټر': 1, 'تېز': 1, 'پيشو': 1, 'د': 1, 'مېز': 1, 'لاندې': 1})
# 117

# %% [markdown]
# **Convert Text → Sequences + Padding**

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
eng_sequence = eng_tokenizer.texts_to_sequences(english)
poshto_sequence = poshto_tokenizer.texts_to_sequences(poshto)

eng_padded = pad_sequences(eng_sequence, padding="post")
poshto_padded = pad_sequences(poshto_sequence, padding='post')

# %% [markdown]
# **Embedding Layer**

# %%
from tensorflow.keras.layers import Embedding
print(len(eng_tokenizer.word_index) + 1)
Embedding_layer = Embedding(input_dim = len(eng_tokenizer.word_index)+1 ,output_dim=64)

embedded_output = Embedding_layer(eng_padded)

print(f'embedding shape :\n {embedded_output.shape}')
print(f'first embeddedd sentence :\n {embedded_output[0]}')
# Out:
# 102
# embedding shape :
#  (50, 6, 64)
# first embeddedd sentence :
#   -0.03012037 -0.0300144  -0.02839547 -0.01085945 -0.03017672 -0.02672223
#    0.01701853  0.02774652  0.00670227 -0.00503784  0.04106417  0.0164382
#    0.02727831 -0.02794331  0.02083758  0.0356156  -0.01183835 -0.02900481
#    0.00210562 -0.03522269 -0.02670145 -0.02417045  0.02375961  0.01902905
#    0.0227353  -0.0456542   0.00657803 -0.02162207  0.02897735 -0.04235761
#    0.01084753  0.04056365 -0.00526867  0.03594282]
#  [ 0.0220753  -0.03404665  0.00722946  0.04046087  0.01984093 -0.03297888
#    0.0256332   0.04011877 -0.03778099  0.02173914 -0.04436816  0.02921077
#    0.04706237  0.01131923 -0.03689946  0.00736199  0.04827771 -0.01555135
#    0.04998707  0.01193313 -0.04444984  0.04621847 -0.0029139   0.03823957
#   -0.00537715  0.03959546  0.022471   -0.00042313  0.03580531 -0.03351676
#   -0.03012037 -0.0300144  -0.02839547 -0.01085945 -0.03017672 -0.02672223
#    0.01701853  0.02774652  0.00670227 -0.00503784  0.04106417  0.0164382
#    0.02727831 -0.02794331  0.02083758  0.0356156  -0.01183835 -0.02900481
#    0.00210562 -0.03522269 -0.02670145 -0.02417045  0.02375961  0.01902905
#    0.0227353  -0.0456542   0.00657803 -0.02162207  0.02897735 -0.04235761
#    0.01084753  0.04056365 -0.00526867  0.03594282]
#  [ 0.0220753  -0.03404665  0.00722946  0.04046087  0.01984093 -0.03297888
#    0.0256332   0.04011877 -0.03778099  0.02173914 -0.04436816  0.02921077
#    0.04706237  0.01131923 -0.03689946  0.00736199  0.04827771 -0.01555135
#    0.04998707  0.01193313 -0.04444984  0.04621847 -0.0029139   0.03823957
#   -0.00537715  0.03959546  0.022471   -0.00042313  0.03580531 -0.03351676
#   -0.03012037 -0.0300144  -0.02839547 -0.01085945 -0.03017672 -0.02672223
#    0.01701853  0.02774652  0.00670227 -0.00503784  0.04106417  0.0164382
#    0.02727831 -0.02794331  0.02083758  0.0356156  -0.01183835 -0.02900481
#    0.00210562 -0.03522269 -0.02670145 -0.02417045  0.02375961  0.01902905
#    0.0227353  -0.0456542   0.00657803 -0.02162207  0.02897735 -0.04235761
#    0.01084753  0.04056365 -0.00526867  0.03594282]]

# %% [markdown]
# **Positional Encoding**
#
# Transformers process all words together, so they do NOT naturally know word order.

# %%
import numpy as np
import tensorflow as tf # Added tensorflow import

def positional_encoding_function(position, d_model):
    # Create an array for positions (0 to position-1)
    pos = np.arange(position)[:, np.newaxis] # shape: (position, 1)
    div_term = 1 / np.power(10000, np.arange(0, d_model, 2) / np.float32(d_model)) # Shape (d_model/2,)

    angle_rads = pos * div_term
    pos_encoding_matrix = np.zeros((position, d_model))
    pos_encoding_matrix[:, 0::2] = np.sin(angle_rads)
    pos_encoding_matrix[:, 1::2] = np.cos(angle_rads)

    pos_encoding = pos_encoding_matrix[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)


# Create positional encoding

# Corrected function call name
pos_encoding = positional_encoding_function(
    position=eng_padded.shape[1],
    d_model=64
)

print("Positional Encoding Shape:")
print(pos_encoding.shape)

transfomer_output = embedded_output + pos_encoding

print("Transformer Output Shape:")
print(transfomer_output.shape)
# Out:
# Positional Encoding Shape:
# (1, 6, 64)
# Transformer Output Shape:
# (50, 6, 64)

# %% [markdown]
# **Build Multi-Head Attention Layer**

# %%
from tensorflow.keras.layers import MultiHeadAttention, LayerNormalization
MultiHeadAttention = MultiHeadAttention(num_heads=4, key_dim=64)

attention_layer_output = MultiHeadAttention(
    query=transfomer_output,
    key=transfomer_output,
    value=transfomer_output
)

print("Attention Layer Output Shape:")
print(attention_layer_output.shape)
# Out:
# Attention Layer Output Shape:
# (50, 6, 64)

# %% [markdown]
# **ADD & NORM (Residual Connection + Layer Normalization)**

# %%
add_output = transfomer_output + attention_layer_output

print("Add & Norm Output Shape:")

layers_normaliztion = LayerNormalization()
norm_output = layers_normaliztion(add_output)

print(norm_output.shape)
# Out:
# Add & Norm Output Shape:
# (50, 6, 64)

# %% [markdown]
# **Feed Forward Network (FFN)**

# %%
from tensorflow.keras.layers import Dense

# Feed Forward Network

ffn = tf.keras.Sequential(
    [
        Dense(256, activation='relu'),
        Dense(64)
    ]
)
ffn_output = ffn(norm_output)

print("FFN Output Shape:")
print(ffn_output.shape)
# Out:
# FFN Output Shape:
# (50, 6, 64)

# %% [markdown]
# **ADD & NORM after FFN**

# %%
add_output_2 = norm_output + ffn_output

print("Add & Norm Output Shape:")

layers_normaliztion_2 = LayerNormalization()
encoder_last_output = layers_normaliztion_2(add_output_2)

print(encoder_last_output.shape)
# Out:
# Add & Norm Output Shape:
# (50, 6, 64)

# %% [markdown]
# the above cell is the last cell of encodding now we start data prefocessing for decodder

# %% [markdown]
# **Decoder Input and Target**

# %%
decoder_input = poshto_padded[:,:-1]
decoder_target = poshto_padded[:,1:]

print("Decoder Input Shape:")
print(decoder_input)

print(f'decoder target :\n {decoder_target}')
# Out:
# Decoder Input Shape:
# [[  1  29   2   0   0   0   0   0]
#  [  1   5  30  31   2   0   0   0]
#  [  1   3  32  11   2   0   0   0]
#  [  1  14  15  12   4   2   0   0]
#  [  1   6  15  33   4   2   0   0]
#  [  1   5  16  34   2   0   0   0]
#  [  1   3  35   5  36   2   0   0]
#  [  1   5  17  37   2   0   0   0]
#  [  1  38   3  17  18   2   0   0]
#  [  1   3  39  13  40  19   2   0]
#  [  1  41  20  21   2   0   0   0]
#  [  1  42  20  21   2   0   0   0]
#  [  1  43  44  13  45   2   0   0]
#  [  1  46  47   2   0   0   0   0]
#  [  1  48   2   0   0   0   0   0]
#  [  1  49  50   8   2   0   0   0]
#  [  1  51  52   8   2   0   0   0]
#  [  1   5  12  53   2   0   0   0]
#  [  1   3  54  55   2   0   0   0]
#  [  1  10   6  56   4   2   0   0]
#  [  1   3  57  11   2   0   0   0]
#  [  1   3  58  11   2   0   0   0]
#  [  1  22  23  59  60  23   2   0]
#  [  1  14  24  61  25   4   2   0]
#  [  1   6  24  62  25   4   2   0]
#  [  1   5  16  63   2   0   0   0]
#  [  1   3  64  65  66  67   2   0]
#  [  1  10  12  68   2   0   0   0]
#  [  1  10  69   4   2   0   0   0]
#  [  1   3  70  18   2   0   0   0]
#  [  1  71  72   4   2   0   0   0]
#  [  1  73   9   8  74  75   7   2]
#  [  1  76   9   8  77   7   2   0]
#  [  1  78  79  80   7   2   0   0]
#  [  1  81  82   7   2   0   0   0]
#  [  1   3  83  84   9  85  86   2]
#  [  1   5  87   5   9   8  88  89]
#  [  1   6  13  26  90   2   0   0]
#  [  1   6  26  91   4   2   0   0]
#  [  1  92  27  93   4   2   0   0]
#  [  1   3  94  95   2   0   0   0]
#  [  1  28   6  96   4   2   0   0]
#  [  1  28   6  97   7   2   0   0]
#  [  1  98   9  99 100   2   0   0]
#  [  1 101 102 103   2   0   0   0]
#  [  1 104 105   4   2   0   0   0]
#  [  1  22 106 107 108   2   0   0]
#  [  1   3 109   5 110  19   2   0]
#  [  1  10 111  27 112   4   2   0]
#  [  1 113 114 115 116   7   2   0]]
# decoder target :
#  [[ 29   2   0   0   0   0   0   0]
#  [  5  30  31   2   0   0   0   0]
#  [  3  32  11   2   0   0   0   0]
#  [ 14  15  12   4   2   0   0   0]
#  [  6  15  33   4   2   0   0   0]
#  [  5  16  34   2   0   0   0   0]
#  [  3  35   5  36   2   0   0   0]
#  [  5  17  37   2   0   0   0   0]
#  [ 38   3  17  18   2   0   0   0]
#  [  3  39  13  40  19   2   0   0]
#  [ 41  20  21   2   0   0   0   0]
#  [ 42  20  21   2   0   0   0   0]
#  [ 43  44  13  45   2   0   0   0]
#  [ 46  47   2   0   0   0   0   0]
#  [ 48   2   0   0   0   0   0   0]
#  [ 49  50   8   2   0   0   0   0]
#  [ 51  52   8   2   0   0   0   0]
#  [  5  12  53   2   0   0   0   0]
#  [  3  54  55   2   0   0   0   0]
#  [ 10   6  56   4   2   0   0   0]
#  [  3  57  11   2   0   0   0   0]
#  [  3  58  11   2   0   0   0   0]
#  [ 22  23  59  60  23   2   0   0]
#  [ 14  24  61  25   4   2   0   0]
#  [  6  24  62  25   4   2   0   0]
#  [  5  16  63   2   0   0   0   0]
#  [  3  64  65  66  67   2   0   0]
#  [ 10  12  68   2   0   0   0   0]
#  [ 10  69   4   2   0   0   0   0]
#  [  3  70  18   2   0   0   0   0]
#  [ 71  72   4   2   0   0   0   0]
#  [ 73   9   8  74  75   7   2   0]
#  [ 76   9   8  77   7   2   0   0]
#  [ 78  79  80   7   2   0   0   0]
#  [ 81  82   7   2   0   0   0   0]
#  [  3  83  84   9  85  86   2   0]
#  [  5  87   5   9   8  88  89   2]
#  [  6  13  26  90   2   0   0   0]
#  [  6  26  91   4   2   0   0   0]
#  [ 92  27  93   4   2   0   0   0]
#  [  3  94  95   2   0   0   0   0]
#  [ 28   6  96   4   2   0   0   0]
#  [ 28   6  97   7   2   0   0   0]
#  [ 98   9  99 100   2   0   0   0]
#  [101 102 103   2   0   0   0   0]
#  [104 105   4   2   0   0   0   0]
#   -3.96359786e-02 -4.85384464e-02 -3.04497778e-04  4.79759462e-02
#   -2.81799920e-02  2.56660022e-02  3.92273776e-02 -1.38118118e-03
#    4.00862843e-03  1.54407062e-02  6.43546507e-03 -1.79413334e-02
#    9.70876217e-03 -8.29238817e-03 -3.43728065e-03 -2.37263739e-04
#   -4.93773483e-02  3.55527550e-03  1.30207799e-02 -2.09518075e-02
#    3.88668664e-02  5.10334969e-03 -1.17913857e-02  1.49271004e-02
#   -1.07039213e-02 -3.19611281e-04 -3.00555583e-02 -2.59414446e-02
#    1.67542584e-02 -1.49145834e-02 -4.04492021e-05 -2.57302877e-02]
#  [ 3.80900986e-02  7.46680424e-03  1.66239478e-02  6.62605837e-03
#    1.57067813e-02  1.11029297e-03  9.95800644e-03 -2.76613720e-02
#   -4.22470830e-02 -1.95304882e-02  4.93571907e-03 -1.50101669e-02
#   -3.93302068e-02 -4.90016006e-02  2.02274211e-02  3.40390205e-03
#   -3.24392542e-02  1.75374486e-02 -4.77484949e-02 -4.39947732e-02
#   -4.96513247e-02 -1.94234606e-02 -1.08649954e-02 -1.61272995e-02
#   -3.15368064e-02 -5.29577583e-03  1.57544129e-02 -2.31738687e-02
#   -3.77038941e-02 -2.32757088e-02 -1.20917335e-02 -3.42190042e-02
#   -3.96359786e-02 -4.85384464e-02 -3.04497778e-04  4.79759462e-02
#   -2.81799920e-02  2.56660022e-02  3.92273776e-02 -1.38118118e-03
#    4.00862843e-03  1.54407062e-02  6.43546507e-03 -1.79413334e-02
#    9.70876217e-03 -8.29238817e-03 -3.43728065e-03 -2.37263739e-04
#   -4.93773483e-02  3.55527550e-03  1.30207799e-02 -2.09518075e-02
#    3.88668664e-02  5.10334969e-03 -1.17913857e-02  1.49271004e-02
#   -1.07039213e-02 -3.19611281e-04 -3.00555583e-02 -2.59414446e-02
#    1.67542584e-02 -1.49145834e-02 -4.04492021e-05 -2.57302877e-02]]

# %% [markdown]
# **positional Endcodding**

# %%
decoder_positional_encoding = positional_encoding_function(position=decoder_embedded_output.shape[1], d_model=64)


#this is new shape of encodded data
decoder_transformer_input = decoder_embedded_output + decoder_positional_encoding

print("Decoder Positional Encoding Shape:")
print(decoder_positional_encoding.shape)
# Out:
# Decoder Positional Encoding Shape:
# (1, 8, 64)

# %% [markdown]
# **MASKED MULTI-HEAD ATTENTION**

# %%
seq_len = decoder_transformer_input.shape[1]
look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)


masked_attention_layer = tf.keras.layers.MultiHeadAttention(
    num_heads=4,
    key_dim=64
)

masked_attention_output = masked_attention_layer(
    query=decoder_transformer_input,
    value=decoder_transformer_input,
    key=decoder_transformer_input,
    attention_mask=look_ahead_mask
)

print("Masked Attention Output Shape:")
print(masked_attention_output.shape)
# Out:
# Masked Attention Output Shape:
# (50, 8, 64)

# %% [markdown]
# **Decoder Add & Norm**

# %%
add_output_3 = decoder_transformer_input + masked_attention_output
print("Add & Norm Output Shape:")

decoder_layers_normaliztion_3 = LayerNormalization()
decoder_last_output_3 = decoder_layers_normaliztion_3(add_output_2)

print(decoder_last_output_3.shape)
# Out:
# Add & Norm Output Shape:
# (50, 6, 64)

# %% [markdown]
# **CROSS ATTENTION**
#
#
# *   decoder connects with encoder
# *   translation understanding happens

# %%
cross_attention = tf.keras.layers.MultiHeadAttention(
    num_heads=4,
    key_dim=64
)

cross_attention_output = cross_attention(
    query= decoder_last_output_3,
    value=encoder_last_output,
    key=encoder_last_output
)

print("Cross Attention Output Shape:")
print(cross_attention_output.shape)
# Out:
# Cross Attention Output Shape:
# (50, 6, 64)

# %% [markdown]
# **Now do Add & Norm after cross attention**

# %%
add_output_4 = decoder_last_output_3 + cross_attention_output
print("Add & Norm Output Shape:")

decoder_layers_normaliztion_4 = LayerNormalization()
decoder_last_output_4 = decoder_layers_normaliztion_4(add_output_4)

print(decoder_last_output_4.shape)
# Out:
# Add & Norm Output Shape:
# (50, 6, 64)

# %% [markdown]
# **last 2nd decoder part feed forword network (ffn)**

# %%
ffn_decoder = tf.keras.Sequential(
    [
        Dense(256, activation='relu'),
        Dense(64)
    ]
)

decoder_ffn_output = ffn_decoder(decoder_last_output_4)

print("FFN Output Shape:")
print(decoder_ffn_output.shape)
# Out:
# FFN Output Shape:
# (50, 6, 64)

# %% [markdown]
# **last add and norm**

# %%
last_add_output = decoder_last_output_4 + decoder_ffn_output
print("Add & Norm Output Shape:")

decoder_layers_normaliztion_5 = LayerNormalization()
decoder_last_output_5 = decoder_layers_normaliztion_5(last_add_output)

print(decoder_last_output_5.shape)
# Out:
# Add & Norm Output Shape:
# (50, 6, 64)

# %% [markdown]
# now kere is full decoder is complete according to blow graph
# ![1_BHzGVskWGS_3jEcYYi6miQ.webp](data:image/webp;base64,...)

# %% [markdown]
# **here the transformer is also complete**

# %% [markdown]
# **OUTPUT PREDICTION LAYER**

# %%
vocab_size = len(poshto_tokenizer.word_index) + 1

last_layer = tf.keras.layers.Dense(units=vocab_size,
                                    activation='softmax')


final_prediction = last_layer(decoder_last_output_5)

print(f'final prediction layer shape : {final_prediction.shape}')
# Out:
# final prediction layer shape : (50, 6, 117)

# %%
import tensorflow as tf

# =========================
# Positional Encoding Layer
# =========================
class PositionalEncodingLayer(tf.keras.layers.Layer):
    def call(self, inputs):
        seq_len = tf.shape(inputs)[1]
        d_model = tf.shape(inputs)[2]

        position = tf.cast(tf.range(seq_len), tf.float32)[:, tf.newaxis]
        i = tf.cast(tf.range(d_model), tf.float32)

        angle_rates = 1 / tf.pow(10000.0, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
        angles = position * angle_rates[tf.newaxis, :]

        pos_encoding = tf.where(i % 2 == 0, tf.sin(angles), tf.cos(angles))

        return inputs + pos_encoding


# =========================
# Look Ahead Mask
# =========================
class LookAheadMaskLayer(tf.keras.layers.Layer):
    def call(self, inputs):
        seq_len = tf.shape(inputs)[1]
        mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
        return mask


d_model = 64
vocab_eng = len(eng_tokenizer.word_index) + 1
vocab_ps = len(poshto_tokenizer.word_index) + 1

# =========================
# Encoder
# =========================
encoder_inputs = tf.keras.Input(shape=(None,), name="encoder_input")

enc_emb = tf.keras.layers.Embedding(vocab_eng, d_model)(encoder_inputs)
enc_emb = PositionalEncodingLayer()(enc_emb)

attn1 = tf.keras.layers.MultiHeadAttention(num_heads=4, key_dim=d_model)(
    enc_emb, enc_emb
)
enc1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(enc_emb + attn1)

ffn1 = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(d_model)
])(enc1)

encoder_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(enc1 + ffn1)


# =========================
# Decoder
# =========================
decoder_inputs = tf.keras.Input(shape=(None,), name="decoder_input")

dec_emb = tf.keras.layers.Embedding(vocab_ps, d_model)(decoder_inputs)
dec_emb = PositionalEncodingLayer()(dec_emb)

mask = LookAheadMaskLayer()(dec_emb)

attn2 = tf.keras.layers.MultiHeadAttention(num_heads=4, key_dim=d_model)(
    dec_emb, dec_emb, attention_mask=mask
)
dec1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(dec_emb + attn2)

attn3 = tf.keras.layers.MultiHeadAttention(num_heads=4, key_dim=d_model)(
    dec1, encoder_output, encoder_output
)
dec2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(dec1 + attn3)

ffn2 = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(d_model)
])(dec2)

dec_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(dec2 + ffn2)


# =========================
# Output Layer (Softmax)
# =========================
outputs = tf.keras.layers.Dense(vocab_ps, activation='softmax')(dec_output)


# =========================
# Final Model
# =========================
model = tf.keras.Model(
    inputs=[encoder_inputs, decoder_inputs],
    outputs=outputs
)

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print(model.summary())


# =========================
# Translation Function
# =========================
def translate(sentence):

    seq = eng_tokenizer.texts_to_sequences([sentence])
    seq = tf.keras.preprocessing.sequence.pad_sequences(
        seq, maxlen=eng_padded.shape[1], padding='post'
    )

    start_id = poshto_tokenizer.word_index["start"]
    end_id = poshto_tokenizer.word_index["end"]

    output_seq = [start_id]

    for _ in range(poshto_padded.shape[1] - 1):

        dec_input = tf.keras.preprocessing.sequence.pad_sequences(
            [output_seq],
            maxlen=poshto_padded.shape[1] - 1,
            padding='post'
        )

        preds = model.predict([seq, dec_input], verbose=0)

        next_id = tf.argmax(preds[0, len(output_seq)-1]).numpy()

        if next_id == end_id:
            break

        output_seq.append(next_id)

    reverse_vocab = {v: k for k, v in poshto_tokenizer.word_index.items()}
    result = [reverse_vocab.get(i, "") for i in output_seq]

    return " ".join(result)


# =========================
# TEST
# =========================
print(translate("hello"))


#the above code have some error
#so please avoid this
# Out:
# Model: "functional_33"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_input       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_8         │ (None, None, 64)  │      6,528 │ encoder_input[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_input       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encodin… │ (None, None, 64)  │          0 │ embedding_8[0][0] │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_9         │ (None, None, 64)  │      7,488 │ decoder_input[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, None, 64)  │     66,368 │ positional_encod… │
# │ (MultiHeadAttentio… │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encodin… │ (None, None, 64)  │          0 │ embedding_9[0][0] │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_88 (Add)        │ (None, None, 64)  │          0 │ positional_encod… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ look_ahead_mask_la… │ (None, None)      │          0 │ positional_encod… │
# │ (LookAheadMaskLaye… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, None, 64)  │        128 │ add_88[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, None, 64)  │     66,368 │ positional_encod… │
# │ (MultiHeadAttentio… │                   │            │ positional_encod… │
# │                     │                   │            │ look_ahead_mask_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_7        │ (None, None, 64)  │     16,576 │ layer_normalizat… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_90 (Add)        │ (None, None, 64)  │          0 │ positional_encod… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_89 (Add)        │ (None, None, 64)  │          0 │ layer_normalizat… │
# │                     │                   │            │ sequential_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, None, 64)  │        128 │ add_90[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, None, 64)  │        128 │ add_89[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, None, 64)  │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_91 (Add)        │ (None, None, 64)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, None, 64)  │        128 │ add_91[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_8        │ (None, None, 64)  │     16,576 │ layer_normalizat… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_92 (Add)        │ (None, None, 64)  │          0 │ layer_normalizat… │
# │                     │                   │            │ sequential_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, None, 64)  │        128 │ add_92[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_84 (Dense)    │ (None, None, 117) │      7,605 │ layer_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 254,517 (994.21 KB)
#  Trainable params: 254,517 (994.21 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# start ځې راتلونکې راتلونکې راتلونکې راتلونکې راتلونکې start start

# %%
print(translate('how are you?'))
# Out:
# start مو مو اوبه اوسېږم اوسېږم اوسېږم مېز مېز

# %% [markdown]
# <a href="https://colab.research.google.com/github/awaiskhan131931-ctrl/transformer/blob/main/tras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Embedding,
    MultiHeadAttention,
    LayerNormalization,
    Dense,
    Dropout
)

# %% [markdown]
# **take a sample**

# %%
sentaces = 'this my new github file'
